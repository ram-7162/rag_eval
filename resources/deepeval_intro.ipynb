# %% [markdown]
# - In DeepEval there is 3 basic components :::
# - (1) LLMTestCase --> represent each case of goldendataset i.e, we convert our samples of dataset in LLMTestCase object
# - (2) Metric --> On what basis we are judging , it can be single or many for same judgement
# - (3) evaluate --> we use (1) and (2) and get output
